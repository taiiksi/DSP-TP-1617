# %% [markdown]
# # Digital Signal Processing
#
# ### MsCV - ViBOT - MAIA

# %% [markdown]
# The reasons to convert signals into frequency domain is to get the idea of different frequency components it is composed of. This might help to detect the required signals and classify them, for examples, speak or speech recognition from a sound wave, noise removal from the image, or finding recurring patterns within images.

# %%
# %matplotlib inline
# %pprint off

# To make some nice plot
import matplotlib.pyplot as plt
# To play with arrays
import numpy as np
from skimage import io
from skimage import img_as_float
from matplotlib import cm
from scipy.stats import norm
from scipy import signal
# Out:
# Pretty printing has been turned ON

# %% [markdown]
# # Discrete Fourier Transform
# The Discrete Fourier Transform (DFT) converts discrete data from a time domain into frequency domain. The DFT analyzes the finite segment in one period of an infinitely extended periodic signal, which is defined as:
# $$ X[n] = \sum^{N-1}_{k = 0} x[k] e^{-j(2\pi/N)kn}$$
#
#
# Note: The Fast Fourier Transform (FFT) is simply an algorithm to compute the DFT in a faster way!
#
# ## Exercise 1 -  ** DFT**
# **1.1** The DFT of a $5$ Hz sin wave sampled with the sampling of $f_s = 50$ Hz over 1000 (N = 1000) samples is computed as follows:

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# sin wave 
x_n = np.sin(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Sin wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.2** Compute the DFT of a cosine wave, how that differs from that of a sine wave ?

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# cos wave 
x_n = np.cos(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('cos wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()


# Only the magnitude part of the dft of the cosine and of the sinus are the same.
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.3** Use square wave using the same frequncy and sampling frequency.
#
# Note use `signal.square` to create your signal.

# %%
from scipy import signal
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for one second
t = np.arange(0, 1., 1./fs)
# square wave 
x_n = signal.square(2*np.pi*f*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('square wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# **1.4** Use white Gaussian noise N = 10000.
#
# (Note use `np.random.normal` to create your noise)

# %%
# Signal frequency and sampling frequency
f = 5.
fs = 50.
# time vector for 20 seconds
t = np.arange(0, 20., 1./fs)
# Gaussian noise  wave 

mu, sigma = 0, 0.1
x_n  = np.random.normal(mu, sigma, 1000)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]

plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('Gaussian noise wave Signal')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()

plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Exercise 2 -  Sampling
#
# Generate and display the following signals of 1 sec duration.
# $$x[n] = 3 cos(2\pi\frac{f_{1}}{f_{s}}n) + 4 sin(2\pi\frac{f_{2}}{f_{s}}n)$$
# for $f_{1} = 5$ Hz and $f_{2} = 20$ Hz, sampled with the sampling frequencies of $f_{s} = [10, 20, 25, 40, 50, 100, 150]$

# %% [markdown]
# **2.1** Plot $x[n]$ for different sampling frequencies in time domain.

# %%
# Signal frequency and sampling frequency
a = 0
f1 = 5.
f2 = 20.
fs = [10, 20, 25, 40, 50, 100, 150]
# time vector for one second
t = np.arange(0, 50., 50./fs[a])
# sin wave 
x_n = 3 * np.cos(2*np.pi*f1/fs[a]*t) + 4 * np.sin(2*np.pi*f2/fs[a]*t)


plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title(' x[n] for sampling frequencie = 10 ')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()



a = 2
# time vector for one second
t = np.arange(0, 50., 50./fs[a])
# sin wave 
x_n = 3 * np.cos(2*np.pi*f1/fs[a]*t) + 4 * np.sin(2*np.pi*f2/fs[a]*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs[a]/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]


plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('x[n] for sampling frequencie = 25')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()




a = 4
# time vector for one second
t = np.arange(0, 50., 50./fs[a])
# sin wave 
x_n = 3 * np.cos(2*np.pi*f1/fs[a]*t) + 4 * np.sin(2*np.pi*f2/fs[a]*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs[a]/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]


plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('x[n] for sampling frequencie = 50')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()





a = 6
# time vector for one second
t = np.arange(0, 50., 50./fs[a])
# sin wave 
x_n = 3 * np.cos(2*np.pi*f1/fs[a]*t) + 4 * np.sin(2*np.pi*f2/fs[a]*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs[a]/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]


plt.figure
plt.subplot(211)
plt.plot(t, x_n)
plt.title('x[n] for sampling frequencie = 150')
plt.xlabel('Time(sec)')
plt.ylabel('Amplitude')
plt.show()





#aliasing effects in the time domain: if we don't take enough points, 
#the interpolation between the points can hide a curve completely different. 
#More a curve has a complex pattern in one period, more we need points to interpolate correctly the signal.

# %% [markdown]
# **2.2.** Discuss the aliasing effects in the time domain:

# %% [markdown]
# **2.3** Compute the FFT of the above signals and display their centered frequency components.
# Discuss your observations.

# %%
# Signal frequency and sampling frequency
a = 0
f1 = 5.
f2 = 20.
fs = [10, 20, 25, 40, 50, 100, 150]
# time vector for one second
t = np.arange(0, 50., 50./fs[a])
# sin wave 
x_n = 3 * np.cos(2*np.pi*f1/fs[a]*t) + 4 * np.sin(2*np.pi*f2/fs[a]*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs[a]/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]


plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT, sampling frequencie = 10')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()




a = 4
# time vector for one second
t = np.arange(0, 50., 50./fs[a])
# sin wave 
x_n = 3 * np.cos(2*np.pi*f1/fs[a]*t) + 4 * np.sin(2*np.pi*f2/fs[a]*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs[a]/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]



plt.subplot(312)
plt.plot(fr, x_f)
plt.title('DFT, sampling frequencie = 50')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.subplot(313)
plt.plot(fr, np.abs(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()





a = 6
# time vector for one second
t = np.arange(0, 50., 50./fs[a])
# sin wave 
x_n = 3 * np.cos(2*np.pi*f1/fs[a]*t) + 4 * np.sin(2*np.pi*f2/fs[a]*t)
# Number of samples 
N = 1000
# frequency vector
fr = (np.arange(-N/2,N/2,1)) * fs[a]/N
# DFT 
# Using fftshift to have the center frequency 
x_f = np.fft.fftshift(np.fft.fft(x_n, N))
#x_f = x_f[0:N/2]



plt.subplot(312)
plt.plot(fr, x_f)  #This plot the real part of the complex number. Equivalent to np.real(x_f)
plt.title('DFT, , sampling frequencie = 150')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()


plt.subplot(313)
plt.plot(fr, np(x_f))
plt.title('Magnitude')
plt.xlabel('Frequency(Hz)')
plt.ylabel('|X(f)|')
plt.show()

plt.figure
plt.subplot(211)
plt.plot(fr, np.real(x_f))
plt.title('Real')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Re(X(f))')
plt.show()

plt.subplot(212)
plt.plot(fr, np.imag(x_f))
plt.title('Imaginary')
plt.xlabel('Frequency(Hz)')
plt.ylabel('Im(X(f))')
plt.show()



# For the imaginary part of the last drawing, the one whose the samling is not too big to recover the signal of 
# combinaison of a sinus and a cosinus, we can recover the imaginary part of the fourier transform of the cosinus 
#and the sinus .
# We can say that for also the real part, the dft, and the amplitude part of the signal.
# We can recover the pattern, but the amplitude and the frequenties are bigger than a purely sinus or a purely cosinus. 



# More the sampling is big, more we need sinus and cosins of different frequencies to represent the signal because the signal 
# looks less like a sinus or a cosinus. 
#So the representation in frequency domain is more and more complex with no clearly pattern.
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\numpy\core\numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-0c9136be7d2e> in <module>()
#     124
#     125 plt.subplot(313)
# --> 126 plt.plot(fr, np(x_f))
#     127 plt.title('Magnitude')
#     128 plt.xlabel('Frequency(Hz)')
#
# TypeError: 'module' object is not callable

# %% [markdown]
# ## Exercise 3 - 1D  DFT for image classification
#
# 1D DFT can be applied to analyze the frequency components along the one dimensional profile of an image. Here we want to use these information to classify the images into two different classes (**barcode** and **non-barcode** classes)
# To do so we first
# * Load the images from 1D-DFT folder
#     * **3.1** you have to normalize and resize the images to the smallest size
#     * **3.2** Take 1D profile as shown in the example and compute its DFT.
# ![](profile1.png)
#
#     * **3.3** Separate the images to two different groups of **barcode** and **non-barcode** based on their frequency spectrum of their profile
# * Some information regarding the images:
#     * There are 54 images while Images [1, 2, 6, 44:54] are barcode images and the others are similar patterns.
#
# **3.4** Discuss your results

# %%
Path = '../images/1D-DFT/'
import os, os.path
from skimage import color
from scipy import misc
from skimage.transform import resize
from skimage.filters import threshold_otsu
from skimage.exposure import rescale_intensity
import math


filenames = sorted([f for f in os.listdir(Path)])

Imgref = io.imread(os.path.join(Path,filenames[0]))  
tempx = Imgref.shape[1]
tempy = Imgref.shape[0]





for f in filenames:
    Img = io.imread(os.path.join(Path,f))  
    minix = Img.shape[1]
    miniy = Img.shape[0]
    if tempx > minix:
        tempx = minix
    if tempy > miniy:
        tempy = miniy
        
        
 
        


Imgref = resize(Imgref, (tempy, tempx))  
Imgref = color.rgb2gray(Imgref)

mini = np.amin(Imgref)
maxi = np.amax(Imgref)


for row in range (0, Imgref.shape[0]):
    for col in range (0, Imgref.shape[1]):
        Imgref[row][col] = (Imgref[row][col] - mini)/(maxi-mini)

        
x_fref = np.fft.fft(Imgref[round(tempy/2), :])



numb = 1

for f in filenames:
    Img = io.imread(os.path.join(Path,f))  
    Img = resize(Img, (tempy, tempx)) 
    Img = color.rgb2gray(Img)


    
    mini = np.amin(Img)
    maxi = np.amax(Img)

    for row in range (0, Img.shape[0]):
        for col in range (0, Img.shape[1]):   
            Img[row][col] = (Img[row][col] - mini)/(maxi-mini)

    
    
    x_f =  np.fft.fftshift(np.fft.fft(Img[round(tempy/2), :]))
    conv = sum(np.convolve(x_fref, x_f))  #Doesn't work

    result = 0
    imagi = np.imag(x_f)
    oldnumber = imagi[0]
    newnumber = imagi[1]
    if oldnumber < newnumber:
        increase = True
    else:
        increase = False

    oldnumber = newnumber   
    for col in range (2, imagi.shape[0]):
            newnumber = imagi[col] 
            if (increase):
                if oldnumber < newnumber:
                    increase = True
                else:
                    increase = False
                    result = result + np.abs(newnumber)
            else:
                if oldnumber < newnumber:
                    increase = True
                    result = result + np.abs(newnumber)
                else:
                    increase = False
            oldnumber = newnumber
                   
            
    
    
    if result > 100:
        plt.subplot(312)
        plt.plot(imagi)
        plt.title('DFT, imaginary part of image number ' + str(numb) + 'sum of peaks:' +  str(result) )
        plt.xlabel('Frequency(Hz)')
        plt.ylabel('|X(f)|')
        plt.show()
    
    
        
    numb = numb + 1
    
    
    


# We can see that the imaginary part of barcodes have more picks and these picks are higher than the
# the imaginary part of non-barcodes
# This doesn't work for the images 10, 13, 28, 32, 47. Error: 100 - (54-5)/54 *100 = 9.25 %
